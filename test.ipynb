# %%
import pandas as pd

df = pd.read_csv("comparison.csv")

# %%
df
# Out:
#                                                Input  \
# 0               What are the causes of hypertension?
# 1                           How is asthma diagnosed?
# 2  Can you provide a brief summary of Hashimoto's...
# 3                   What are the symptoms of anemia?
# 4                What is the treatment for migraine?
# 5  What is the difference between Type 1 and Type...
# 6                 How can osteoporosis be prevented?
# 7   What are the early signs of Alzheimer's disease?
#
#                                original model Output  \
# 0  ### Input:\nWhat are the causes of hypertensio...
# 1                                         ### Input:
# 2  ### Input:\nCan you provide a brief summary of...
# 3                                                NaN
# 4                                                NaN
# 5  Type 1 diabetes is characterized by hyperglyce...
# 6                                                NaN
# 7  ### Input:\n\n### Input:\n\n### Input:\n\n### ...
#
# ...
